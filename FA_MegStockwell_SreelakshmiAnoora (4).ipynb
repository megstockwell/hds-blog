# %% [markdown]
# <a href="https://colab.research.google.com/github/megstockwell/hds-blog/blob/main/FA_MegStockwell_SreelakshmiAnoora%20(4).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![alt text](https://drive.google.com/uc?export=view&id=1DXUVHxd4t15mfuqMgMCLnsP4jWVI5EWz)
#
# ---
#
# <br>
# © 2023 Copyright The University of New South Wales - CRICOS 00098G
#
# **Authors**: Oscar Perez-Concha.
#
# **Communications**: If you have any questions, please email Oscar at: o.perezconcha@unsw.edu.au

# %% [markdown]
# # Final Assignment (FA)

# %% [markdown]
# ---

# %% [markdown]
# #####################################################################################
#
# **Meg Stockwell:**
#
# **Honour Pledge** <p>
#
# Declaration: <p>
#
#
# I declare that this assessment item is my own work, except where acknowledged, and has not been submitted for academic credit elsewhere or previously, or produced independently of this course (e.g. for a third party such as your place of employment) and acknowledge that the assessor of this item may, for the purpose of assessing this item:
#
# 1. Reproduce this assessment item and provide a copy to another member of the University; and/or
#
# 2. Communicate a copy of this assessment item to a plagiarism checking service (which may then retain a copy of the assessment item on its database for the purpose of future plagiarism checking).
#
# **By writing you name and surname above, you certify that you have read and agreed to the honour pledge.**
#
# #####################################################################################

# %% [markdown]
# #####################################################################################
#
# **Sreelakshmi Anoora:**
#
# **Honour Pledge** <p>
#
#
# Declaration: <p>
#
#
# I declare that this assessment item is my own work, except where acknowledged, and has not been submitted for academic credit elsewhere or previously, or produced independently of this course (e.g. for a third party such as your place of employment) and acknowledge that the assessor of this item may, for the purpose of assessing this item:
#
# 1. Reproduce this assessment item and provide a copy to another member of the University; and/or
#
# 2. Communicate a copy of this assessment item to a plagiarism checking service (which may then retain a copy of the assessment item on its database for the purpose of future plagiarism checking).
#
# **By wrting you name and surname above, you certify that you have read and agreed to the honour pledge.**
#
# #####################################################################################

# %% [markdown]
# ---
# # 1.  Health Data Science Scenario
#
# ## 1.1. Research Question
#
# Our hospital has been very proactive in analysing data from its Electronic Medical Records (EMR). Through this analysis, we've made some interesting discoveries.
#
# We identified that readmitted patients are not only those who were sicker during their first admission but also those with less support after discharge or those without medical follow-up post-discharge.
# Readmitted patients experienced high levels of emotional stress.
# Readmitted patients were at a significantly higher risk of acquiring new infections while in the hospital.
# Readmissions are highly costly. Patients who were readmitted for the reasons mentioned above tended to be sicker than during their first admission, and their length of stay was significantly longer than during their first admission.

# %% [markdown]
# Our hospital has implemented a pilot program named "Redesigning Discharge," which involves a "specialised unit" that coordinates patients' discharges. This pilot program has been running for a year.
#
# This "specialised unit" is composed of a team of doctors, nurses, physiotherapists, and occupational therapists.
#
# The program consists of two main innovations.
#
# 1. In the first part of the program, the doctors conduct a new discharge assessment protocol using innovative evidence-based tools to help them decide whether patients are ready to return to their usual place of residence or if it would be more advisable to transfer them to an intermediate or short-term care facility. As such, this program is set to replace the previous protocol concerning where patients should be discharged.
#
# 2. The second part of the program includes a group of nurses, physiotherapists, and occupational therapists who visit patients at home or in the intermediate facility after discharge. The frequency of these visits is determined by an assessment conducted prior to discharge, averaging about five visits per patient. Among other things, the team's tasks include ensuring proper wound healing, checking medication compliance, coordinating with a general practitioner or the medical team at the intermediate facility, and assessing the patient's ability to perform basic daily activities such as navigating their environment, using the toilet, and showering. Furthermore, the specialised unit maintains regular telephone contact with patients to check on their well-being. Patients are also encouraged to reach out to the unit if they need any assistance.
#
# This pilot program has been very successful and it has been welcomed by all the stakeholders. Among other things, the program has significantly reduced the number of hospital readmissions. Moreover, the operating costs for this specialised unit have proven to be considerably lower than the costs associated with readmissions

# %% [markdown]
# In terms of budget:
#
# 1. The average cost of a day in the hospital is 6,000 dollars; readmitted patients tend to stay for an average of 4 days.
#
# 2. An intervention by the specialised unit costs on average 2,000 dollars, which includes the cost of the average number of visits per patient, being 5 visits.
#
# 3. The cost of an intermediate facility is not considered, as it's covered by Private Health Insurance or other Government Schemes. Additionally, our program is effectively 'donating' a team of medical professionals to these facilities. Therefore, we do not need to account for the cost of these intermediate facilities if a patient is discharged there.
#
# Our hospital is now prepared to implement "Redesigning Discharge" and extend the specialized unit service to all patients at risk of readmission. The challenge we face, however, is that we cannot predict in advance which patients are at risk of readmission. As such, we are currently unable to identify the specific patients we should be targeting

# %% [markdown]
# Our research aims to address the following questions:
#
# 1. Can we develop a machine learning algorithm that can predict the probability of a patient's readmission within 30 days before their discharge?
#
# 2. How can we effectively communicate the performance and benefits of this algorithm to the hospital managers, enabling them to make an informed decision about its implementation?
#
# The main challenge we face is not only the development of an effective predictive algorithm, but also explaining its complexities in a clear, digestible manner for non-technical decision-makers.

# %% [markdown]
# ---

# %% [markdown]
# '## 1.2. Instructions
#
# 1.  We aim to develop a predictive model to forecast hospital readmissions within 30 days of discharge.
#
# > Consider the next points:
#
# > The predictive model will be run prior to discharge, and before a decision has been made regarding the need for the specialized unit or the place of discharge.
#
# > This forecast will primarly aid doctors and other clinicians in making a final decision about whether a patient will need the "specialised unit" or not.
#
# > In addition, as part of the new protocol, this forecast will also help decide whether the patient should return to their usual place of residence or be transferred to an intermediate facility. This new protocol is set to replace the previous one concerning where patients should be discharged.
#
# > We plan to use historical data from the hospital for this purpose. Unfortunately, the historical data with which we have been provided doesn't include any record of the pilot study that ran for a year, which could have assisted in training our model.
#
#
# 2. Review the research questions and make the appropriate decisions for building this predictive model, in accordance with the research question text.
#
#
# 3.   Thoroughly review and study the data provided. Please pay close attention to the data dictionary (PDF inside the data folder) and revisit the plots and graphs created during weeks 1, 2, and 3.
#
# 4. Given that the hospital has already provided the data, we'll bypass the following steps in the health data science workflow (refer to the image below): Step 3 and substeps 3a,3b,3c,3d,3e: Data Gathering.
#
# 5. In Step 4, substep 4a (Data visualization), visualize the data in your drafts, but do not include the graphs in your final submission.
#
# 6. The hospital aims to capture as many "readmissions" as possible (true positives), even if this moderately increases the number of false positives within reason (i.e., patients not at risk of readmission classified as such). However, be mindful that the hospital does not have unlimited resources. An excessive number of patients identified as at-risk could inflate the operational costs of the "specialised unit" beyond sustainable levels.
#
# 7. The data scientists at the hospital have asked that you only consider the Logistic Regression and Random Forest machine learning techniques.
#
# 8. Design various machine learning algorithms with different hyperparameters. Select one and provide a rationale for your choice.
#
# 9. Use the classification_report and confusion matrix metrics for model evaluation. If you use other metrics such as the ROC curve, do not include them in your final submission.
#
# 10. Justification for your decisions is crucial. Provide a one or two sentence explanation for each section preceding the relevant Python code block. You are encouraged to use "Sanity Checks" during the construction of the algorithms. Please do not include them in your final submission.
#
# 11. Ensure clear labels for printed results and briefly detail the steps followed.
#
# 12. Remember to comment and document your code thoroughly, as this will likely serve as a foundation for team-based algorithm development in the future.
#
# 13. Format: Jupyter Notebook.
#
# 14. Programming Language: Python.
#
# 15. Submission: Upload the Jupyter Notebook to the designated section in OpenLearning and on your GitHub space. Submissions will close precisely at the deadline.
#
# 16. Only submit the final version of your document.
#
# 17. Include your first and last names in the document's title. For example: Final-Assignment-AnnXu-MichaelRoss.ipynb
#
# 18. Each question is worth 1 mark, except question 8, which is worth 2 marks.
#
# 19. Marks will be deducted for failure to follow the previous instructions.
#
# 20. Refer to the provided [rubric](https://unsw-my.sharepoint.com/:w:/g/personal/z3368601_ad_unsw_edu_au/EYaMoVWZ20hFoj9R8hL2PIIB4-ACN6c4bf4uCI66gzpEqA?e=tUJZiB).

# %% [markdown]
# ![alt text](https://drive.google.com/uc?export=view&id=105SGqeyo8RgLhSO8mN7ZE5OsG0YiLPKt)

# %% [markdown]
# ## 1.3. Late Submission Penalty
#
# UNSW has a [standard](https://www.unsw.edu.au/arts-design-architecture/student-life/resources-support/protocols-guidelines)  late submission penalty of:
#
#
# *   5% per day,
# *   for all assessments where a penalty applies,
# *   capped at five days (120 hours) from the assessment deadline, after which a student cannot submit an assessment,
# *   and no permitted variation.
#
# Students are expected to manage their time to meet deadlines and to request extensions as early as possible before the deadline.

# %% [markdown]
# ## 1.4. Marks and Feedback
#
# Per UNSW's policy, the marks and feedback of this assignment will be released after UNSW releases the final marks.

# %% [markdown]
# ---

# %% [markdown]
# ## 1.5. Provided Python Code

# %%
# check required libraries are installed if not calling system to install
import sys
import subprocess
import pkg_resources

required = {'numpy', 'pandas', 'plotnine', 'matplotlib', 'seaborn',
            'grid', 'shap', 'scikit-learn'}
installed = {pkg.key for pkg in pkg_resources.working_set}
missing = required - installed

if missing:
    print('Installing: ', missing)
    python = sys.executable
    subprocess.check_call([python, '-m', 'pip', 'install', *missing], stdout=subprocess.DEVNULL)
# delete unwanted variables
del required
del installed
del missing
# Out:
# Installing:  {'shap', 'grid'}

# %%
# Mount Google Drive
# We do not need to run this cell if you are not running this notebook in Google Colab

if 'google.colab' in str(get_ipython()):
    from google.colab import drive # import drive from Gogle colab
    root = '/content/drive'     # default location for the drive
    # print(root)                 # print content of ROOT (Optional)
    drive.mount(root)
else:
    print('Not running on CoLab')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Change the project paths and the paths according to where you have placed your files:

# %%
from pathlib import Path

if 'google.colab' in str(get_ipython()):
    # EDIT THE PROJECT PATH IF DIFFERENT WITH YOUR ONE
    project_path = Path(root) / 'MyDrive' / 'HDAT9500' / 'final_assignment'

    # OPTIONAL - set working directory according to your google drive project path
    # import os
    # Change directory to the location defined in project_path
    # os.chdir(project_path)
else:
    project_path = Path()

# %% [markdown]
# ---
# Function to plot the confusion matrix:

# %%
def plot_confusion_matrix(confusion_matrix):
  # visualise the confusion matrix
  labels = ['No', 'Yes']
  ax = plt.subplot()
  sns.heatmap(confusion_matrix, annot = True, fmt = '.0f', ax = ax, cmap = 'viridis')

  # labels, titles and ticks
  ax.set_xlabel('Predicted labels')
  ax.set_ylabel('True labels')
  ax.set_title('Confusion Matrix')
  ax.xaxis.set_ticklabels(labels)
  ax.yaxis.set_ticklabels(labels)

# %%
# General imports
import sys
import numpy as np
import pandas as pd
from IPython.display import display
import seaborn as sns
import matplotlib.pyplot as plt
import warnings; warnings.simplefilter('ignore')

# Question-specific imports
import pickle # Question 2
from sklearn.model_selection import train_test_split # Question 3
from sklearn.linear_model import LogisticRegression # Question 4
from sklearn.preprocessing import StandardScaler # Question 4
from sklearn.pipeline import Pipeline # Question 4
from sklearn.metrics import f1_score # Question 4
from sklearn.model_selection import GridSearchCV # Questions 4 and 6
from sklearn.ensemble import RandomForestClassifier # Question 6
from sklearn.metrics import classification_report # Questions 5 and 7
from sklearn.metrics import confusion_matrix # Questions 5 and 7
import shap # Question 9

# %% [markdown]
# ---

# %% [markdown]
# ---
# # 2. Questions:

# %% [markdown]
# ## Question 1: Docstring
#
# Create a docstring that includes the following:
#
# 1. Purpose: The top-level aim of our program. (Please limit this to 50 words).
# 2. Author(s)
# 3. Dates
# 4. List of Variables, Constants, and Functions: Describe how each one is used in the program. Ensure that you choose informative variable names and thoroughly document your program (both through docstrings and comments). When required, units should accompany the variables. The list of variables must be written in different sections: General, Question 1, Question 2, ..., Question 9. For the list of variables within each section, list the variables, constants, and functions in alphabetical order.
# 5. Method: The "Method" section in a docstring typically refers to the approach or algorithm used in the program or function. Here, you would describe the sequence of operations or steps your code follows to accomplish its goal.
#
# Structure your docstring into distinct sections, with one section per point listed above.

# %% [markdown]
# <b> 1. Purpose: The aim of our program</b>
#
# ################################################################################
#
# The aim of our program is to develop, evaluate and compare two predictive models to forecast hospital readmissions within 30 days of discharge, using logistic regression and random forest modelling techniques.
# ################################################################################

# %% [markdown]
# <b> 2. Author(s): The author(s) of this program</b>
#
# ################################################################################
#
# The authors of this program are Meg Stockwell and Sreelakshmi Anoora.
#
# ################################################################################

# %% [markdown]
# <b> 3. Date: The date this program was completed </b>
#
# ################################################################################
#
# This program was completed on 30/07/2023.
#
# ################################################################################

# %% [markdown]
# <b> 4. List of variables, constants and functions in alphabetical order:</b>
#
# ################################################################################
#
# <b> General: </b>
#
# * `hospital` : provided hospital dataset containing 'Diabetes inpatient encounters 130 USA hospitals (1999-2008)'.
# * `hospital_clean` : cleaned version of the `hospital` dataset with the non-informative columns removed.
# * `pickle_path` : path to the location of `hospital` data.
# * `plot_confusion_matrix`: function to plot a given confusion matrix.
# * `project_path`: path to the location of the project.
#
# ---
#
# <b> Question 2: Preparation of data. </b>
#
# * `discharge_vars` : variables from the `hospital` dataset related to discharge of the patient.
# * `f_readmission`: Function for converting categorical readmission values to binary.
# * `readmission_int`: binary version of the outcome (readmission) variable from the `hospital` dataset generated by `f_readmission()`.
# * `X`: matrix of features from the `hospital_clean` dataset.
# * `y`: matrix of outcomes from the `hospital_clean` dataset.
#
# ---
#
# <b> Question 3: </b>
#
# * `X_test` : testing data extracted from the `X` features dataset.
# * `X_train` : training data extracted from the `X` features dataset.
# * `y_test` : testing data extracted from the `Y` outcomes dataset.
# * `y_train` : training data extracted from the `Y` outcomes dataset.
#
# ---
# <b> Question 4: Training, and hyper-parameter tuning of the Logistic Regression model.</b>
#
# * `grid_search_LR`: Logistic Regression model trained and tuned using the `X_train` predictors, `y_train` outcomes, `param_grid_LR` hyperparameters and `pipeln` modelling pipeline.
# * `log_reg`: Logistic Regression function used to build the `grid_search_LR` Logistic Regression model.
# * `param_grid_LR`: parameter grid of the Logistic Regression hyperparameter options for tuning by the `grid_search_LR` Logistic Regression model.
# * `pipeln` : modelling pipeline for tranformation and estimation of the Logistic Regression model.
# * `standard_scaler`: scaler function used in the `pipeln` modelling pipeline.
#
# ---
#
# <b>Question 5: Evaluation of the Logistic Regression model. </b>
#
# * `confusion_LR_test`: confusion matrix derived from `y_test` and `y_pred_LR_test` for the logistic regression model `grid_search_LR` evaluated on the test set.
# * `confusion_LR_train`: confusion matrix derived from `y_train` and `y_pred_LR_train` for the logistic regression model `grid_search_LR` evaluated on the training set.
# * `y_pred_LR_test`: predictions of the outcome for the logistic regression model `grid_search_LR` evaluated on the test set.
# * `y_pred_LR_train`: predictions of the outcome for the logistic regression model `grid_search_LR` evaluated on the training set.
#
# ---
#
# <b>Question 6: Training, and hyper-parameter tuning of the Random Forest model. </b>
#
# * `grid_search_RF`: Random Forest model trained and tuned using the `X_train` predictors, `y_train` outcomes, `param_grid_RF` hyperparameters and `RF_classifier` classifier.
# * `param_grid_RF`: parameter grid of the Random Forest hyperparameter options for tuning by the `grid_search_RF` Random Forest model.
# * `RF_classifier`: Random Forest classifier used to build the `grid_search_RF` Random Forest model.
#
# ---
#
# <b>Question 7: Evaluation of the Random Forest model. </b>
#
# * `confusion_RF_test`: confusion matrix derived from `y_test` and `y_pred_RF_test` for the random forest model `grid_search_RF` evaluated on the test set.
# * `confusion_RF_train`: confusion matrix derived from `y_train` and `y_pred_RF_train` for the random forest model `grid_search_RF` evaluated on the training set.
# * `y_pred_RF_test`: predictions of the outcome for the random forest model `grid_search_RF` evaluated on the test set.
# * `y_pred_RF_train`: predictions of the outcome for the random forest model `grid_search_RF` evaluated on the training set.
#
# ---
#
# <b>Question 9: SHAP analysis. </b>
#
# * `explainer_RF`: the SHAP tree explainer method for estimating the `grid_search_RF` Random Forest model SHAP values.
# * `shap_values_explainer_RF`: the SHAP values estimated for the `grid_search_RF` Random Forest model using the `explainer_RF` explainer.
#
# ################################################################################

# %% [markdown]
# <b> 5. Method: The steps used to complete this project </b>
#
# ################################################################################
#
# To achieve the aim set out in section `1`, the following steps were performed:
# * Import and prepare the provided hospital data for modelling, removing any non-informative variables and dividing the data into features and outcomes
# * Split the data into training and test datasets
# * Train and tune the hyperparameters of the logistic regression model
# * Evaluate the logistic regression model with the best hyperparameters achieved.
# * Train and tune the hyperparameters of the random forest model
# * Evaluate the random forest model with the best hyperparameters achieved.
# * Compare the models and determine whether either should be deployed
# * Implement SHAP for the final model and describe the results
#
# ################################################################################

# %% [markdown]
# ---

# %% [markdown]
# ---
# ## Question 2: Read and check the pickle file provided. Prepare the data so it can be used by the algorithms that you are going to create.
# ---

# %% [markdown]
# <b> Rationale: What are you doing to solve this question? - 75 word count limit:</b>
#
#
# ################################################################################
#
# We first imported the provided data from the path, then dropped the ID variables as they are non informative in modelling. We also dropped all the discharge related information as this model is used prior to discharge and any information related to discharge can't be used then. We created an integer column for readmission as required for the models and separated the input features to X and output to y for modelling.
#
# ################################################################################

# %%
# Python code here (15 lines limit, 1 cell limit)

# Import the pickle file
pickle_path = Path(project_path) / 'data' / 'hospital_data_final_assignment.pickle'

# Load the provided dataset in pickle format
with open(pickle_path, 'rb') as data: hospital = pickle.load(data)

# Drop the id variables
hospital_clean = hospital.drop(['admission_id','patient_id'], axis = 1)

# Drop the discharge variables
discharge_vars = hospital_clean.columns[hospital_clean.columns.str.startswith('discharge_')]
hospital_clean = hospital_clean.drop(discharge_vars, axis = 1)

# Create new readmission integer column
def f_readmission(row):
    if row['readmission'] == 'yes':
        readmission_int = 1
    else:
        readmission_int = 0
    return  readmission_int

# Add new column readmission_int to our dataframe or panda.
hospital_clean['readmission_int'] = hospital_clean.apply(f_readmission,axis=1)

# Assign X (features) and y (outcome) data
X = hospital_clean.drop(axis=1, columns=['readmission', 'readmission_int'])
y = hospital_clean.loc[:,['readmission_int']]

# %% [markdown]
# ---
# ## Question 3: Divide the data into 80% for training and 20% for testing, using a random seed of 30. Set the other hyperparameters as you deem appropriate.
# ---

# %% [markdown]
# <b> Rationale: What are you doing to solve this question?- 75 word count limit:</b>
#
#
# ################################################################################
#
# We used train_test_split() to split data for X(input) and y(output) into training and testing datasets in the advised proportions, to hide the test set during training process. test_size = 0.2(20 %) and train_size takes the complementary value by default. We used random_seed = 30 as advised for reproducible output across multiple function calls and set stratify = y to maintain the same proportion of y in both data sets as it is an imbalanced dataset.
#
# ################################################################################

# %%
# Python code here (2 lines limit, and 1 cell limit)

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30, stratify=y)
# Stratify=y used because the dataset is imbalanced

# %% [markdown]
# ---

# %% [markdown]
# ---
# ## Question 4: Train and tune the hyperparameters of the Logistic Regression model.
#
# Hyper-parameters:
#
# - `C` values: 10, 100.
# - `class_weight`: only two pairs. Choose one of these two combinations and explain why.
#
#     * A weight of (80% for class 1, 20% for class 0) and (70% for class 1, 30% for class 0)
#     * A weight of (80% for class 0, 20% for class 1) and (70% for class 0, 30% for class 1).
#
# - `penalty` values: elasticnet, None
# - 3-fold cross-validation for the grid search.
# - `f1` as the score to choose the best model in the grid search.
# - `n_jobs`=-1.
# - do not include the heatmaps in the final submission.
# - do not change these hyper-parameters.
# - keep the remaining set of hyper-parameters in the default state.
# ---

# %% [markdown]
# <b> Rationale: What are you doing to solve this question?-100 word count limit:</b>
#
#
# ################################################################################
#
# Used LogisticRegression() with given conditions, however we had to:
# * Use solver=’saga’ because elasticnet supports only saga, not default='lbfgs'
# * Increase max_iter from 100(default) to 1000 to allow solvers to converge.
# * Find an optimum value for l1_ratio using param_grid and use this in the log_reg, as it is required by elasticnet (ignored when penalty=None).
#
# We chose class weight option 1 because only 17% of the dataset belongs to class 1 and a larger weight is required to correct the data imbalance. We used a pipeline to perform sequential standardisation and estimation, and param_grid and grid_searchCV to find and fit the best model.
#
#
# ################################################################################

# %%
# Python code here (15 lines limit, and 2 cells limit)

# Scaler object
standard_scaler = StandardScaler()

# Classification model using L1 regularisation
log_reg = LogisticRegression(n_jobs = -1, solver = 'saga', max_iter = 1000, l1_ratio = 0.1)

# Pipeline
pipeln = Pipeline([('Transform', standard_scaler), ('Estimator', log_reg)])

# Defining the hyper-parameters grid
param_grid_LR = {'Estimator__penalty' : ['elasticnet', None], 'Estimator__C': [10, 100],
                 'Estimator__class_weight': [{0:0.2,1:0.8},{0:0.3,1:0.7}]}

# %%
# Define gridsearch object for Logistic Regression model
grid_search_LR = GridSearchCV(pipeln, param_grid = param_grid_LR, cv = 3, scoring='f1')

# Fitting the model with all combinations in param_grid to get the best model
grid_search_LR.fit(X_train, y_train.values.ravel())
# y_train.values.ravel used to convert column-vector to 1d array, which is the shape required by this function

# Printing the best parameters obtained from the gridsearch
print("Best parameters: \n{}".format(grid_search_LR.best_params_))
print("Best cross-validation score: {:.4f}".format(grid_search_LR.best_score_))
# Out:
# Best parameters:
# {'Estimator__C': 10, 'Estimator__class_weight': {0: 0.3, 1: 0.7}, 'Estimator__penalty': 'elasticnet'}
# Best cross-validation score: 0.9238

# %% [markdown]
# ---

# %% [markdown]
# ---
# ## Question 5: Evaluate the Logistic Regression model on both the training and test sets. Use the `plot_confusion_matrix(confusion_matrix)` function provided above to display the results.
# ---

# %% [markdown]
# <b> Rationale: Why are we evaluating the model in the training set? Why are we evaluating the model in the test set? What are you doing to solve this question?- 120 word count limit:</b>
#
#
# ################################################################################
#
# It is important to evaluate the models in both training and test data to evaluate its performance - good performance on both training and test data is desired. Better performance on training set and poor performance on test set indicates overfitting of training data. Poor performance on training set means underfitting. Evaluation of model on test data is very important to know how well the model generalises to new and real data which increases the credibility of the model. With the identified better performing hyperparameters we fit the model on the training and test data and evaluate the performance on both sets of data using confusion matrix and classification report to determine the generalisability and performance of the model achieved.
#
# ################################################################################

# %%
# Python code here (10 lines limit, and 2 cells limit)

# Evaluate the model on the training set
y_pred_LR_train = grid_search_LR.predict(X_train)

# Print the classification report
print("\tClassification report of training set")
print(classification_report(y_train, y_pred_LR_train))

# Generate confusion matrix for evaluation
confusion_LR_train = confusion_matrix(y_train, y_pred_LR_train)
plot_confusion_matrix(confusion_LR_train)
# Out:
# 	Classification report of training set
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98     45878
#            1       0.89      0.96      0.93      9535
#
#     accuracy                           0.97     55413
#    macro avg       0.94      0.97      0.95     55413
# weighted avg       0.97      0.97      0.97     55413

# %%
# Evaluate the model on the test set
y_pred_LR_test = grid_search_LR.predict(X_test)

# Print the classification report
print("\tClassification report of test set")
print(classification_report(y_test, y_pred_LR_test))

# Generate confusion matrix for evaluation of test set
confusion_LR_test = confusion_matrix(y_test, y_pred_LR_test)
plot_confusion_matrix(confusion_LR_test)
# Out:
# 	Classification report of test set
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98     11470
#            1       0.89      0.96      0.92      2384
#
#     accuracy                           0.97     13854
#    macro avg       0.94      0.97      0.95     13854
# weighted avg       0.97      0.97      0.97     13854

# %% [markdown]
# ---

# %% [markdown]
# ---
# ## Question 6: Train and tune the hyperparameters of the of the Random Forest model.
#
# Fixed hyper-parameters (do not change the values of these hyper-parameters):
#
# - `n_estimators`: 125, 150
# - `class_weight`: Only two pairs. Choose one of these two combinations (either combination 1 or combination 2) and explain why.
# 1. A weight of (80% for class 1, 20% for class 0) and (70% for class 1, 30% for class 0)
# 2.  A weight of (80% for class 0, 20% for class 1) and (70% for class 0, 30% for class 1).
# - 3-fold cross-validation for the grid search.
# - Select the score to choose the best model in the grid search.
# - `n_jobs`=-1
# - do not include the heatmaps in the final submission
#
# Other hyper-parameters:
#
# - `max_features`: 20, 30
# - `min_samples_split`: 20, 25
# - you can change the previous hyper-parameters (`max_features` and `min_samples_split`) or add other hyper-parameters if you wish. An explanation must be given to why you made that decision.
#
# ---

# %% [markdown]
# <b> Rationale: What are you doing to solve this question?-150 word count limit:</b>
#
#
# ################################################################################
#
# Using the random forest classifier for our model, we set the random state to zero to achieve the same results each time and set n_jobs to -1 to parallelise the model fitting with all processors. We then defined a parameter grid with the initial options for the remaining hyperparameters. For class_weight, we used the first of the two combinations for testing, to upweight the readmission=1 records that were underrepresented in the data. We then performed a 3-fold cross validation to automatically select and fit a model with the best hyperparameters from our list and used f1 scoring to keep the results comparable to the logistic regression model. We used a heatmap to visualise the results of the hyperparameter selections and tested additional options that were close to the best selections for max_features and min_samples_split. We did not tune the max_depth parameter as the depth is already influenced by min_samples_split.
#
#
# ################################################################################

# %%
# Python code here (15 lines limit, and 2 cells limit)

# Define random forest classifier and its fixed hyperparameters
RF_classifier = RandomForestClassifier(random_state=0,n_jobs=-1)
# Random state defined, because the results are not otherwise consistent each time the model is run

# Define parameter grid for variable hyperparameters
param_grid_RF = {'n_estimators': [125,150], # Number of trees in forest
              'max_features': [10,20,30,40], # Number of features to consider when looking for the best split
              'min_samples_split': [2,3,4,5,10,15,20,25], # Minimum number of samples required to be at a leaf node
              'class_weight': [{0:0.2,1:0.8},{0:0.3,1:0.7}]} # Weights associated with classes

# Perform a 3-fold cross-validated grid-search over the parameter grid using f1 scoring
grid_search_RF = GridSearchCV(RF_classifier, param_grid=param_grid_RF, cv=3, scoring = 'f1')
grid_search_RF.fit(X_train, y_train.values.ravel())
# y_train.values.ravel used to convert column-vector to 1d array, which is the shape required by this function

# Print the best parameters found and the related f1 score
print("Best parameters: {}".format(grid_search_RF.best_params_))
print("Best cross-validation average f1 score: {:.2f}".format(grid_search_RF.best_score_))
# Out:
# Best parameters: {'class_weight': {0: 0.2, 1: 0.8}, 'max_features': 20, 'min_samples_split': 3, 'n_estimators': 125}
# Best cross-validation average f1 score: 0.94

# %% [markdown]
# ---

# %% [markdown]
# ---
# ## Question 7: Evaluate the Random Forest model on both the training and test sets. Use the `plot_confusion_matrix(confusion_matrix)` function provided above to display the results.
# ---

# %% [markdown]
# <b> Rationale: Why are we evaluating the model in the training set? Why are we evaluating the model in the test set? What are you doing to solve this question?- 120 word count limit:</b>
#
# ################################################################################
#
# We evaluate how the model performs on the training set to determine whether the model fits the “seen” data and on the test set to determine whether the model can generalise to the “unseen” data. If performance on the training set is poor, the model is likely underfitting and if performance on the training set is good but performance on the test set is bad, the model is likely overfitting. In both cases the model should be adjusted. To evaluate our model, we predicted the outcome (readmission) for each patient on the training and test sets using our random forest classifier and assessed how the results compared to their actual outcomes using a confusion matrix and classification report.
#
# ################################################################################

# %%
# Python code here (10 lines limit, and 2 cells limit)

# Make predictions using the training set
y_pred_RF_train= grid_search_RF.predict(X_train)

# Produce classification report
print("\tClassification report of training set")
print(classification_report(y_train, y_pred_RF_train))

# Calculate and plot confusion matrix
confusion_RF_train = confusion_matrix(y_true = y_train, y_pred = y_pred_RF_train)
plot_confusion_matrix(confusion_RF_train)
# Out:
# 	Classification report of training set
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     45878
#            1       1.00      1.00      1.00      9535
#
#     accuracy                           1.00     55413
#    macro avg       1.00      1.00      1.00     55413
# weighted avg       1.00      1.00      1.00     55413

# %%
# Make predictions using the test set
y_pred_RF_test = grid_search_RF.predict(X_test)

# Produce classification report
print("\tClassification report of test set")
print(classification_report(y_test, y_pred_RF_test))

confusion_RF_test = confusion_matrix(y_true = y_test, y_pred = y_pred_RF_test) # Test set
plot_confusion_matrix(confusion_RF_test)
# Out:
# 	Classification report of test set
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     11470
#            1       0.94      0.96      0.95      2384
#
#     accuracy                           0.98     13854
#    macro avg       0.96      0.97      0.97     13854
# weighted avg       0.98      0.98      0.98     13854

# %% [markdown]
# ---

# %% [markdown]
# ---
# ## Question 8: Based on the research questions and instructions, determine which model, if any, you would choose. Justify whether or not you would deploy this model.
# ---

# %% [markdown]
# <b> Rationale: 350 word count limit </b>
#
# ################################################################################
#
# To capture as many readmissions as possible, we need the sensitivity (TP/(TP+FN)) to be high. For both models, the sensitivity is approximately 0.96 (with 4% of readmitted patients being missed). To avoid identifying an excessive number of patients as at-risk however, we also want to minimise the number of false positives and therefore maximise the specificity (TN/(TN+FP)). For the logistic regression model, the specificity is 0.975 (with 2.5% of patients being incorrectly identified as readmitted) and for the random forest model, it is 0.986 (with 1.4% of patients being incorrectly identified as readmitted). This suggests that the random forest model may be better for capturing our needs in this scenario. This is further supported by the f1 scores of the model, which are 0.92 for the logistic regression and 0.94 for the random forest model.
#
# Despite the high performance of the models, however, I would not deploy either model to all patients at this stage. This is because:
# * The random forest model reports precision, recall and f1 scores of 1.0 on the training data – this suggests that it may be overfitting and may not generalise well to unseen data.
# * 4% of readmitted patients are still misclassified as non risky for readmission– however these patients are at higher risk of acquiring new infections, high levels of emotional stress and are likely to incur higher costs than if they were pre-identified and sent to the specialised unit.
# * The dataset only captures records for diabetes inpatient encounters, however readmissions can occur for many reasons and to other kinds of patients.
# * The dataset only captures data from 1999-2008 and many factors, such as diagnosis codes, may have changed since then – this would mean the data is trained on different parameters to those seen in current clinical settings, causing the predictions to be less accurate.
#
# ################################################################################

# %% [markdown]
# ---

# %% [markdown]
# ---
# ## Question 9:  Implement SHAP for the final model and describe your observations. If no model was selected in question 8, provide a justification and choose one model specifically for this SHAP analysis. Conclude by commenting on the results.
# ---

# %% [markdown]
# <b> Explanation of what you observe - 250 word count limit:</b>
#
# ################################################################################
#
# SHAP values show both feature importance and also whether each  feature has a positive or negative impact on predictions. We use SHAP below to visualise the effect of all the features in the 'X_train' dataset of the random forest model.
#
# The bar plot below shows that los (which has the longest bar) is by far the most important predictor within this model, followed by number_outpatient, admission_type_grouped_emergency and admission_type_grouped_elective. As the width of the bars for class 0 and class 1 are essentially equal, it also shows that the magnitude or impact of features on each class are the same, though they may be in different directions (positive vs negative impact).
#
# The beeswarm plot adds further information, showing that:
# * A higher length of stay is indicative of a higher risk of readmission
# * A higher number of outpatient visits in the preceeding year is indicative of a higher risk of readmission
# * An Emergency admission is indicative of a higher risk of readmission
# * An Elective admission is indicative of a lower risk of readmission
# * Higher numbers of medications given and lab procedures performed are indicative of a lower risk of readmission
# * A higher number of diagnoses is indicative of a higher risk of readmission
# ... and so on.
#
# These findings make clinical sense and suggest that the model is making appropriate predictions. Similar impacts are seen when analysing the SHAP results on the test data, though the order of importance of each feature changes slightly.
#
#
# ################################################################################

# %%
# Python code here (10 lines limit, and 2 cells limit)

# Use SHAP to explain predictions
explainer_RF = shap.TreeExplainer(grid_search_RF.best_estimator_,X_train)
shap_values_explainer_RF = explainer_RF.shap_values(X_train)

# Display summary bar plot
shap.summary_plot(shap_values_explainer_RF,X_train,feature_names=X_train.columns)
# Out:
# 100%|===================| 110801/110826 [46:19<00:00]

# %%
# Display summary beeswarm plot
shap.summary_plot(shap_values_explainer_RF[1], X_train)

# %% [markdown]
# ---

# %% [markdown]
# © 2023 Copyright The University of New South Wales - CRICOS 00098G
